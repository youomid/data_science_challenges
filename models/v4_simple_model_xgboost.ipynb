# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import train_test_split

import mlflow
import mlflow.xgboost

# %%
DATASET_NAME = 'dataset_v2'
train_df = pd.read_csv(f'../output/train_{DATASET_NAME}.csv')
train_df, valid_df = train_test_split(train_df, test_size=0.2)
train_df.head()
# Out:
#             id    qid1    qid2  \
# 393363  393366  526154  526155
# 165293  165294  256693  256694
# 259051  259053  374759  374760
# 151975  151976   21507   87432
# 126744  126745  143926  204202
#
#                                                 question1  \
# 393363  Suggest a best app to download videos or songs...
# 165293         What are the merchant marine requirements?
# 259051             How do I club multiple personal loans?
# 151975  What should one do to find purpose of one's life?
# 126744                       Does pure love really exist?
#
#                                                 question2  is_duplicate  \
# 393363                    Why the fall of China worry us?             0
# 165293  How can the effects of osmosis on cells be exp...             0
# 259051              Can you have multiple personal loans?             0
# 151975                  What is the purpose of your life?             1
# 126744                    Does true and pure love exists?             1
#
#                                          question1_lemma  \
# 393363  suggest best app download video song window lap
# 165293                     merchant marine requirements
# 259051                     club multiple personal loans
# 151975                        one find purpose one life
# 126744                           pure love really exist
#
#                        question2_lemma  simple_ratio  partial_ratio  ...  \
# 393363            fall china worry us             33             35  ...
# 165293  effect osmosis cell explained             32             41  ...
# 259051        multiple personal loans             76            100  ...
# 151975                   purpose life             58             77  ...
# 126744          true pure love exists             56             68  ...
#
#         question1_punctuation_count  question2_punctuation_count  \
# 393363                            1                            1
# 165293                            1                            1
# 259051                            1                            1
# 151975                            2                            1
# 126744                            1                            1
#
#                                            question1_hash  \
# 393363  Suggest a best app to download videos or songs...
# 165293         What are the merchant marine requirements?
# 259051             How do I club multiple personal loans?
# 151975  What should one do to find purpose of one's life?
# 126744                       Does pure love really exist?
#
#                                            question2_hash  question1_degree  \
# 393363                    Why the fall of China worry us?                 1
# 165293  How can the effects of osmosis on cells be exp...                 2
# 259051              Can you have multiple personal loans?                 1
# 151975                  What is the purpose of your life?                12
# 126744                    Does true and pure love exists?                 3
#
#         question2_degree  question1_degree_deviation  \
# 393363                 1                   -0.504718
# 165293                 1                    0.495282
# 259051                 1                   -0.504718
# 151975                41                   10.495282
# 126744                 5                    1.495282
#
#         question2_degree_deviation match_share tfidf_word_match_share
# 393363                   -0.504718    0.000000               0.000000
# 165293                   -0.504718    0.000000               0.000000
# 259051                   -0.504718    0.857143               0.852760
# 151975                   39.495282    0.571429               0.608611
# 126744                    3.495282    0.500000               0.494909
#
# [5 rows x 26 columns]

# %%
features = [
    'simple_ratio',
    'partial_ratio',
    'token_sort_ratio',
    'token_set_ratio',
    'question1_type',
    'question2_type',
    'question1_punctuation_count',
    'question2_punctuation_count',
    'match_share',
    'tfidf_word_match_share'
    ]

train_is_duplicate_df = train_df[['is_duplicate']].copy()
train_features_df = train_df[features].copy()

valid_is_duplicate_df = valid_df[['is_duplicate']].copy()
valid_features_df = valid_df[features].copy()

# %%
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.02
params['max_depth'] = 4

num_boost_round = 400
n_fold = 5
early_stopping_rounds=50

with mlflow.start_run():
    d_train = xgb.DMatrix(train_features_df, label=train_is_duplicate_df)
    d_valid = xgb.DMatrix(valid_features_df, label=valid_is_duplicate_df)

    watchlist = [(d_train, 'train'), (d_valid, 'valid')]

    bst = xgb.train(params, d_train, num_boost_round, watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=10)
    
    cv_results = xgb.cv ( 
        params, 
        d_train, 
        num_boost_round = num_boost_round, 
        seed = 42, 
        nfold = n_fold, 
        early_stopping_rounds = early_stopping_rounds,
        verbose_eval=10
    ) 
    
    mlflow.log_param('features', ','.join(features))
    mlflow.log_param('objective', params['objective'])
    mlflow.log_param('eval_metric', params['eval_metric'])
    mlflow.log_param('eta', params['eta'])
    mlflow.log_param('max_depth', params['max_depth'])
    
    mlflow.log_param('num_boost_round', num_boost_round)
    mlflow.log_param('n_fold', n_fold)
    mlflow.log_param('early_stopping_rounds', early_stopping_rounds)
    
    mlflow.log_metric('train_logloss', cv_results.to_dict()['train-logloss-mean'][num_boost_round-1])
    mlflow.log_metric('valid_logloss', cv_results.to_dict()['test-logloss-mean'][num_boost_round-1])
    
    mlflow.xgboost.log_model(bst, 'quora_xgb')
# Out:
# [0]	train-logloss:0.68590	valid-logloss:0.68584
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# [10]	train-logloss:0.62650	valid-logloss:0.62635
# [20]	train-logloss:0.58488	valid-logloss:0.58463
# [30]	train-logloss:0.55435	valid-logloss:0.55407
# [40]	train-logloss:0.53135	valid-logloss:0.53103
# [50]	train-logloss:0.51379	valid-logloss:0.51345
# [60]	train-logloss:0.50025	valid-logloss:0.49987
# [70]	train-logloss:0.48952	valid-logloss:0.48916
# [80]	train-logloss:0.48106	valid-logloss:0.48073
# [90]	train-logloss:0.47452	valid-logloss:0.47419
# [100]	train-logloss:0.46937	valid-logloss:0.46908
# [110]	train-logloss:0.46530	valid-logloss:0.46504
# [120]	train-logloss:0.46197	valid-logloss:0.46178
# [130]	train-logloss:0.45931	valid-logloss:0.45916
# [140]	train-logloss:0.45719	valid-logloss:0.45707
# [150]	train-logloss:0.45544	valid-logloss:0.45535
# [160]	train-logloss:0.45393	valid-logloss:0.45390
# [170]	train-logloss:0.45263	valid-logloss:0.45262
# [180]	train-logloss:0.45154	valid-logloss:0.45156
# [190]	train-logloss:0.45047	valid-logloss:0.45052
# [200]	train-logloss:0.44947	valid-logloss:0.44960
# [210]	train-logloss:0.44867	valid-logloss:0.44885
# [220]	train-logloss:0.44801	valid-logloss:0.44824
# [230]	train-logloss:0.44743	valid-logloss:0.44772
# [240]	train-logloss:0.44686	valid-logloss:0.44718
# [250]	train-logloss:0.44640	valid-logloss:0.44676
# [260]	train-logloss:0.44582	valid-logloss:0.44625
# [270]	train-logloss:0.44534	valid-logloss:0.44582
# [280]	train-logloss:0.44484	valid-logloss:0.44537
# [290]	train-logloss:0.44442	valid-logloss:0.44498
# [300]	train-logloss:0.44401	valid-logloss:0.44463
# [310]	train-logloss:0.44357	valid-logloss:0.44425
# [320]	train-logloss:0.44305	valid-logloss:0.44381
# [330]	train-logloss:0.44251	valid-logloss:0.44333
# [340]	train-logloss:0.44208	valid-logloss:0.44296
# [350]	train-logloss:0.44168	valid-logloss:0.44261
# [360]	train-logloss:0.44126	valid-logloss:0.44224
# [370]	train-logloss:0.44091	valid-logloss:0.44193
# [380]	train-logloss:0.44055	valid-logloss:0.44162
# [390]	train-logloss:0.44018	valid-logloss:0.44130
# [399]	train-logloss:0.43992	valid-logloss:0.44109
# [0]	train-logloss:0.68586+0.00002	test-logloss:0.68587+0.00002
# [10]	train-logloss:0.62647+0.00007	test-logloss:0.62652+0.00017
# [20]	train-logloss:0.58479+0.00011	test-logloss:0.58487+0.00036
# [30]	train-logloss:0.55428+0.00014	test-logloss:0.55440+0.00048
# [40]	train-logloss:0.53123+0.00019	test-logloss:0.53139+0.00053
# [50]	train-logloss:0.51370+0.00021	test-logloss:0.51387+0.00062
# [60]	train-logloss:0.50021+0.00020	test-logloss:0.50041+0.00072
# [70]	train-logloss:0.48939+0.00026	test-logloss:0.48963+0.00080
# [80]	train-logloss:0.48102+0.00024	test-logloss:0.48130+0.00086
# [90]	train-logloss:0.47445+0.00023	test-logloss:0.47478+0.00088
# [100]	train-logloss:0.46926+0.00026	test-logloss:0.46959+0.00089
# [110]	train-logloss:0.46518+0.00026	test-logloss:0.46555+0.00092
# [120]	train-logloss:0.46189+0.00027	test-logloss:0.46230+0.00095
# [130]	train-logloss:0.45922+0.00029	test-logloss:0.45967+0.00095
# [140]	train-logloss:0.45707+0.00027	test-logloss:0.45754+0.00096
# [150]	train-logloss:0.45533+0.00029	test-logloss:0.45584+0.00098
# [160]	train-logloss:0.45383+0.00029	test-logloss:0.45436+0.00098
# [170]	train-logloss:0.45252+0.00027	test-logloss:0.45308+0.00101
# [180]	train-logloss:0.45138+0.00026	test-logloss:0.45197+0.00102
# [190]	train-logloss:0.45034+0.00024	test-logloss:0.45096+0.00106
# [200]	train-logloss:0.44938+0.00025	test-logloss:0.45003+0.00106
# [210]	train-logloss:0.44855+0.00026	test-logloss:0.44924+0.00106
# [220]	train-logloss:0.44786+0.00026	test-logloss:0.44857+0.00106
# [230]	train-logloss:0.44724+0.00025	test-logloss:0.44798+0.00109
# [240]	train-logloss:0.44669+0.00025	test-logloss:0.44746+0.00108
# [250]	train-logloss:0.44620+0.00026	test-logloss:0.44699+0.00109
# [260]	train-logloss:0.44567+0.00026	test-logloss:0.44650+0.00109
# [270]	train-logloss:0.44515+0.00029	test-logloss:0.44602+0.00105
# [280]	train-logloss:0.44470+0.00027	test-logloss:0.44560+0.00106
# [290]	train-logloss:0.44429+0.00028	test-logloss:0.44521+0.00106
# [300]	train-logloss:0.44387+0.00026	test-logloss:0.44484+0.00108
# [310]	train-logloss:0.44343+0.00027	test-logloss:0.44441+0.00109
# [320]	train-logloss:0.44290+0.00027	test-logloss:0.44393+0.00110
# [330]	train-logloss:0.44243+0.00028	test-logloss:0.44350+0.00109
# [340]	train-logloss:0.44197+0.00029	test-logloss:0.44308+0.00109
# [350]	train-logloss:0.44157+0.00033	test-logloss:0.44272+0.00105
# [360]	train-logloss:0.44117+0.00034	test-logloss:0.44235+0.00106
# [370]	train-logloss:0.44079+0.00033	test-logloss:0.44202+0.00106
# [380]	train-logloss:0.44044+0.00034	test-logloss:0.44170+0.00106
# [390]	train-logloss:0.44009+0.00034	test-logloss:0.44140+0.00108
# [399]	train-logloss:0.43979+0.00032	test-logloss:0.44114+0.00110

# %%
bst.get_fscore()
# Out:
# {'match_share': 1532,
#  'partial_ratio': 965,
#  'token_sort_ratio': 923,
#  'token_set_ratio': 372,
#  'simple_ratio': 342,
#  'question1_type': 411,
#  'tfidf_word_match_share': 627,
#  'question2_punctuation_count': 293,
#  'question1_punctuation_count': 181,
#  'question2_type': 281}
