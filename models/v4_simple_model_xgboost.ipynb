# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import train_test_split

import mlflow
import mlflow.xgboost

# %%
DATASET_NAME = 'dataset_v2'
train_df = pd.read_csv(f'../output/train_{DATASET_NAME}.csv')
train_df, valid_df = train_test_split(train_df, test_size=0.2)
train_df.head()
# Out:
#             id    qid1    qid2  \
# 348693  348695  477279  477280
# 153068  153069  209100  240362
# 10558    10558   20442   20443
# 60936    60936  106487  106488
# 25021    25021   46671   46672
#
#                                                 question1  \
# 348693  How do I focus on studies without getting dist...
# 153068  Where can I get best photo booth hire in and a...
# 10558   If I delete a contact on whatsapp and my main ...
# 60936   Who are some of greatest people in the world t...
# 25021        How do you get free checks from Wells Fargo?
#
#                                                 question2  is_duplicate  \
# 348693  I'm in class 12. I have a very good understand...             0
# 153068  Where can I find best photo booth Company in S...             1
# 10558   If I deactivate my WhatsApp account and then r...             0
# 60936   What are some good "social experiments" for ge...             0
# 25021   How much does it cost to get a safe deposit bo...             0
#
#                                           question1_lemma  \
# 348693     focus study without get distract feel someone
# 153068           get best photo booth hire around sydney
# 10558   delete contact whatsapp main contact list  con...
# 60936           greatest people world step comfort zones
# 25021                         get free check wells fargo
#
#                                           question2_lemma  simple_ratio  \
# 348693  class 12  good understand physic never get goo...            30
# 153068              find best photo booth company sydney             59
# 10558   deactivate whatsapp account reactivate later  ...            51
# 60936         good  social experiments  get comfort zone             44
# 25021     much doe cost get safe deposit box wells fargo             40
#
#         partial_ratio  ...  question1_degree  question2_degree  \
# 348693             39  ...                 1                 1
# 153068             76  ...                 3                 2
# 10558              65  ...                 4                 2
# 60936              54  ...                 1                 1
# 25021              63  ...                 1                 1
#
#         question1_degree_deviation  question2_degree_deviation  \
# 348693                   -0.264051                   -0.264051
# 153068                    0.782280                    0.259114
# 10558                     1.305445                    0.259114
# 60936                    -0.264051                   -0.264051
# 25021                    -0.264051                   -0.264051
#
#         question1_second_order_total_degree  \
# 348693                                    1
# 153068                                    7
# 10558                                    12
# 60936                                     1
# 25021                                     1
#
#         question2_second_order_total_degree  question1_max_kcore  \
# 348693                                    1                    0
# 153068                                    5                    0
# 10558                                     6                    0
# 60936                                     1                    0
# 25021                                     1                    0
#
#         question2_max_kcore match_share tfidf_word_match_share
# 348693                    0    0.000000               0.000000
# 153068                    0    0.615385               0.648491
# 10558                     0    0.416667               0.372969
# 60936                     0    0.166667               0.221396
# 25021                     0    0.461538               0.435291
#
# [5 rows x 68 columns]

# %%
features = [
    'simple_ratio',
    'partial_ratio',
    'token_sort_ratio',
    'token_set_ratio',
    'question1_type',
    'question2_type',
    'question1_punctuation_count',
    'question2_punctuation_count',
    'match_share',
    'tfidf_word_match_share',
    'question1_degree',
    'question2_degree',
    'question1_degree_deviation',
    'question2_degree_deviation',
    'question1_second_order_total_degree',
    'question2_second_order_total_degree',
    'question1_max_kcore',
    'question2_max_kcore',
    ]

train_is_duplicate_df = train_df[['is_duplicate']].copy()
train_features_df = train_df[features].copy()

valid_is_duplicate_df = valid_df[['is_duplicate']].copy()
valid_features_df = valid_df[features].copy()

# %%
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.02
params['max_depth'] = 4

num_boost_round = 400
n_fold = 5
early_stopping_rounds=50

with mlflow.start_run():
    d_train = xgb.DMatrix(train_features_df, label=train_is_duplicate_df)
    d_valid = xgb.DMatrix(valid_features_df, label=valid_is_duplicate_df)

    watchlist = [(d_train, 'train'), (d_valid, 'valid')]

    bst = xgb.train(params, d_train, num_boost_round, watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=10)
    
    cv_results = xgb.cv ( 
        params, 
        d_train, 
        num_boost_round = num_boost_round, 
        seed = 42, 
        nfold = n_fold, 
        early_stopping_rounds = early_stopping_rounds,
        verbose_eval=10
    ) 
    
    mlflow.log_param('features', ','.join(features))
    mlflow.log_param('objective', params['objective'])
    mlflow.log_param('eval_metric', params['eval_metric'])
    mlflow.log_param('eta', params['eta'])
    mlflow.log_param('max_depth', params['max_depth'])
    
    mlflow.log_param('num_boost_round', num_boost_round)
    mlflow.log_param('n_fold', n_fold)
    mlflow.log_param('early_stopping_rounds', early_stopping_rounds)
    
    mlflow.log_metric('train_logloss', cv_results.to_dict()['train-logloss-mean'][num_boost_round-1])
    mlflow.log_metric('valid_logloss', cv_results.to_dict()['test-logloss-mean'][num_boost_round-1])
    
    mlflow.xgboost.log_model(bst, 'quora_xgb')
# Out:
# [0]	train-logloss:0.68331	valid-logloss:0.68329
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# [10]	train-logloss:0.60204	valid-logloss:0.60167
# [20]	train-logloss:0.54389	valid-logloss:0.54343
# [30]	train-logloss:0.50123	valid-logloss:0.50049
# [40]	train-logloss:0.46833	valid-logloss:0.46732
# [50]	train-logloss:0.44270	valid-logloss:0.44152
# [60]	train-logloss:0.42224	valid-logloss:0.42085
# [70]	train-logloss:0.40587	valid-logloss:0.40437
# [80]	train-logloss:0.39306	valid-logloss:0.39159
# [90]	train-logloss:0.38248	valid-logloss:0.38098
# [100]	train-logloss:0.37387	valid-logloss:0.37233
# [110]	train-logloss:0.36702	valid-logloss:0.36556
# [120]	train-logloss:0.36121	valid-logloss:0.35978
# [130]	train-logloss:0.35670	valid-logloss:0.35531
# [140]	train-logloss:0.35218	valid-logloss:0.35082
# [150]	train-logloss:0.34837	valid-logloss:0.34696
# [160]	train-logloss:0.34541	valid-logloss:0.34393
# [170]	train-logloss:0.34221	valid-logloss:0.34070
# [180]	train-logloss:0.33958	valid-logloss:0.33800
# [190]	train-logloss:0.33753	valid-logloss:0.33594
# [200]	train-logloss:0.33566	valid-logloss:0.33410
# [210]	train-logloss:0.33375	valid-logloss:0.33223
# [220]	train-logloss:0.33177	valid-logloss:0.33029
# [230]	train-logloss:0.32984	valid-logloss:0.32841
# [240]	train-logloss:0.32826	valid-logloss:0.32690
# [250]	train-logloss:0.32680	valid-logloss:0.32548
# [260]	train-logloss:0.32531	valid-logloss:0.32400
# [270]	train-logloss:0.32402	valid-logloss:0.32272
# [280]	train-logloss:0.32295	valid-logloss:0.32167
# [290]	train-logloss:0.32191	valid-logloss:0.32064
# [300]	train-logloss:0.32071	valid-logloss:0.31949
# [310]	train-logloss:0.31968	valid-logloss:0.31851
# [320]	train-logloss:0.31863	valid-logloss:0.31751
# [330]	train-logloss:0.31753	valid-logloss:0.31647
# [340]	train-logloss:0.31639	valid-logloss:0.31540
# [350]	train-logloss:0.31511	valid-logloss:0.31418
# [360]	train-logloss:0.31394	valid-logloss:0.31306
# [370]	train-logloss:0.31295	valid-logloss:0.31214
# [380]	train-logloss:0.31180	valid-logloss:0.31104
# [390]	train-logloss:0.31076	valid-logloss:0.31007
# [399]	train-logloss:0.30999	valid-logloss:0.30937
# [0]	train-logloss:0.68326+0.00008	test-logloss:0.68327+0.00007
# [10]	train-logloss:0.60209+0.00032	test-logloss:0.60215+0.00015
# [20]	train-logloss:0.54393+0.00020	test-logloss:0.54405+0.00043
# [30]	train-logloss:0.50125+0.00027	test-logloss:0.50139+0.00053
# [40]	train-logloss:0.46845+0.00028	test-logloss:0.46867+0.00071
# [50]	train-logloss:0.44283+0.00027	test-logloss:0.44310+0.00086
# [60]	train-logloss:0.42225+0.00029	test-logloss:0.42256+0.00100
# [70]	train-logloss:0.40576+0.00033	test-logloss:0.40610+0.00101
# [80]	train-logloss:0.39290+0.00035	test-logloss:0.39326+0.00099
# [90]	train-logloss:0.38242+0.00033	test-logloss:0.38283+0.00105
# [100]	train-logloss:0.37380+0.00027	test-logloss:0.37424+0.00118
# [110]	train-logloss:0.36682+0.00035	test-logloss:0.36728+0.00114
# [120]	train-logloss:0.36108+0.00031	test-logloss:0.36158+0.00117
# [130]	train-logloss:0.35631+0.00030	test-logloss:0.35684+0.00124
# [140]	train-logloss:0.35206+0.00040	test-logloss:0.35262+0.00117
# [150]	train-logloss:0.34829+0.00031	test-logloss:0.34889+0.00132
# [160]	train-logloss:0.34491+0.00038	test-logloss:0.34555+0.00119
# [170]	train-logloss:0.34197+0.00025	test-logloss:0.34265+0.00135
# [180]	train-logloss:0.33953+0.00024	test-logloss:0.34023+0.00136
# [190]	train-logloss:0.33738+0.00034	test-logloss:0.33811+0.00134
# [200]	train-logloss:0.33536+0.00020	test-logloss:0.33614+0.00144
# [210]	train-logloss:0.33359+0.00017	test-logloss:0.33441+0.00149
# [220]	train-logloss:0.33173+0.00024	test-logloss:0.33258+0.00153
# [230]	train-logloss:0.32994+0.00025	test-logloss:0.33084+0.00150
# [240]	train-logloss:0.32814+0.00029	test-logloss:0.32908+0.00151
# [250]	train-logloss:0.32662+0.00033	test-logloss:0.32759+0.00150
# [260]	train-logloss:0.32512+0.00035	test-logloss:0.32614+0.00153
# [270]	train-logloss:0.32397+0.00034	test-logloss:0.32503+0.00157
# [280]	train-logloss:0.32286+0.00037	test-logloss:0.32395+0.00158
# [290]	train-logloss:0.32173+0.00044	test-logloss:0.32287+0.00152
# [300]	train-logloss:0.32060+0.00043	test-logloss:0.32178+0.00157
# [310]	train-logloss:0.31946+0.00040	test-logloss:0.32068+0.00161
# [320]	train-logloss:0.31834+0.00038	test-logloss:0.31959+0.00169
# [330]	train-logloss:0.31711+0.00034	test-logloss:0.31839+0.00170
# [340]	train-logloss:0.31586+0.00047	test-logloss:0.31718+0.00161
# [350]	train-logloss:0.31468+0.00049	test-logloss:0.31603+0.00161
# [360]	train-logloss:0.31362+0.00056	test-logloss:0.31501+0.00155
# [370]	train-logloss:0.31261+0.00058	test-logloss:0.31404+0.00155
# [380]	train-logloss:0.31169+0.00065	test-logloss:0.31315+0.00150
# [390]	train-logloss:0.31074+0.00074	test-logloss:0.31223+0.00141
# [399]	train-logloss:0.30988+0.00077	test-logloss:0.31140+0.00143

# %%
bst.get_fscore()
# Out:
# {'match_share': 984,
#  'question1_second_order_total_degree': 718,
#  'question2_second_order_total_degree': 638,
#  'simple_ratio': 127,
#  'token_sort_ratio': 633,
#  'question2_degree': 1026,
#  'question1_degree': 717,
#  'token_set_ratio': 237,
#  'tfidf_word_match_share': 192,
#  'partial_ratio': 365,
#  'question1_type': 142,
#  'question2_type': 91,
#  'question2_punctuation_count': 56,
#  'question1_punctuation_count': 54}
